# %%
# check vibronic lineshapes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from spectro.utils import vibronic_emission, vibronic_ls, vibronic_intensity

# %%
# %matplotlib notebook

# %%
def vibronic_emission_v2(x, amp, e0, hrs, sigma, gamma, e_vib, kt=0, **kw):
    return vibronic_ls(-(x-e0), hrs, sigma, gamma, e_vib, kt=kt, **kw)*amp

# %%
x = np.linspace(1.8, 2.2, 1000)
hrs = 0.2
kt = 0.025
e_vib = 0.025
sigma = 0.001
gamma = 0.001
e0 = 2

ls = vibronic_ls(-(x-e0), hrs, sigma, gamma, e_vib, kt)
emls  = vibronic_emission(x, 1, e0, hrs, sigma, gamma, e_vib, kt)
em_v2 = vibronic_emission_v2(x, 1, e0, hrs, sigma, gamma, e_vib, kt)

assert np.allclose(ls, emls)
assert np.allclose(ls, em_v2)

# %%
plt.figure()
plt.plot(x, ls)
plt.plot(x, emls)
plt.plot(x, em_v2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.linspace(1.8, 2.5, 1000)
y1 = vibronic_emission(x, 1, 2.17, 0.5, 0.01, 0.001, 0.07, 0)
y2 = vibronic_emission(x, 1, 2.17, 0.5, 0.01, 0.001, 0.07, 0.025)
y3 = vibronic_emission(x, 1, 2.17, 0.5, 0.01, 0.001, 0.07, 0.2)
plt.figure()
plt.plot(x, y1, label="kT=0")
plt.plot(x, y2, label="kT=RT")
plt.plot(x, y3, label="kT=200 meV")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
